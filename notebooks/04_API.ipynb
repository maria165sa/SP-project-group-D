# %% [markdown]
# # Phase 3- API and deployment
#
# **Master's Thesis Project - Biomedical Engineering**
#
# ## Overview
# This notebook demonstrates the complete deployment pipeline for a machine learning model that predicts 10-year coronary heart disease (CHD) risk. The model was trained on the Framingham Heart Study dataset and deployed via a FastAPI REST API with a React frontend.
